# %%
f = open('input6.txt')
data = f.readlines()
# data
data.append('\n')

# %%
dic = {}
sum_count = 0
for line in data:
#     print(data[i])
    print(line)
    if line == '\n':
        sum_count = sum_count + len(dic.keys())
        print(sum_count, dic)
        dic = {}
        continue
    else:
        for element in line:
            if element == '\n':
                continue
            else: dic[element] = 1
count
# Out:
# elmcifawqgkp
#
# dynwslejfcrkpv
#
#
#
# 19 {'e': 1, 'l': 1, 'm': 1, 'c': 1, 'i': 1, 'f': 1, 'a': 1, 'w': 1, 'q': 1, 'g': 1, 'k': 1, 'p': 1, 'd': 1, 'y': 1, 'n': 1, 's': 1, 'j': 1, 'r': 1, 'v': 1}
# pagrovuzscemqiy
#
# paxomsgyuvc
#
#
#
# 35 {'p': 1, 'a': 1, 'g': 1, 'r': 1, 'o': 1, 'v': 1, 'u': 1, 'z': 1, 's': 1, 'c': 1, 'e': 1, 'm': 1, 'q': 1, 'i': 1, 'y': 1, 'x': 1}
# hcoljgiraqvs
#
# hgrvxqcojal
#
# arjhqclogv
#
# jlrvackhogq
#
#
#
# 49 {'h': 1, 'c': 1, 'o': 1, 'l': 1, 'j': 1, 'g': 1, 'i': 1, 'r': 1, 'a': 1, 'q': 1, 'v': 1, 's': 1, 'x': 1, 'k': 1}
# bagctysnmhodfe
#
# tfchsdoeagmnby
#
# csdhnotbfgayme
#
#
#
# 63 {'b': 1, 'a': 1, 'g': 1, 'c': 1, 't': 1, 'y': 1, 's': 1, 'n': 1, 'm': 1, 'h': 1, 'o': 1, 'd': 1, 'f': 1, 'e': 1}
# rksnmhbxi
#
# dyhavkcjrp
#
#
#
# 79 {'r': 1, 'k': 1, 's': 1, 'n': 1, 'm': 1, 'h': 1, 'b': 1, 'x': 1, 'i': 1, 'd': 1, 'y': 1, 'a': 1, 'v': 1, 'c': 1, 'j': 1, 'p': 1}
# t
#
# tx
#
# t
#
#
#
# 81 {'t': 1, 'x': 1}
# fd
#
# of
#
# wejznfa
#
# f
#
# fs
#
#
#
# ...

# %%
dic = {}
sum_count = 0
count_ppl = 0
for line in data:
#     print(data[i])
#     print(line)
    if line == '\n':
        for key in dic:
            if dic[key] == count_ppl:
                sum_count += 1
        print(sum_count, dic, count_ppl)
        dic = {}
        count_ppl = 0
        continue
    else:
        count_ppl += 1
        for element in line:
            if element == '\n':
                continue
            elif element not in dic: 
                dic[element] = 1
            else:
                dic[element] = dic[element] + 1
count
# Out:
# 7 {'e': 2, 'l': 2, 'm': 1, 'c': 2, 'i': 1, 'f': 2, 'a': 1, 'w': 2, 'q': 1, 'g': 1, 'k': 2, 'p': 2, 'd': 1, 'y': 1, 'n': 1, 's': 1, 'j': 1, 'r': 1, 'v': 1} 2
# 17 {'p': 2, 'a': 2, 'g': 2, 'r': 1, 'o': 2, 'v': 2, 'u': 2, 'z': 1, 's': 2, 'c': 2, 'e': 1, 'm': 2, 'q': 1, 'i': 1, 'y': 2, 'x': 1} 2
# 27 {'h': 4, 'c': 4, 'o': 4, 'l': 4, 'j': 4, 'g': 4, 'i': 1, 'r': 4, 'a': 4, 'q': 4, 'v': 4, 's': 1, 'x': 1, 'k': 1} 4
# 41 {'b': 3, 'a': 3, 'g': 3, 'c': 3, 't': 3, 'y': 3, 's': 3, 'n': 3, 'm': 3, 'h': 3, 'o': 3, 'd': 3, 'f': 3, 'e': 3} 3
# 44 {'r': 2, 'k': 2, 's': 1, 'n': 1, 'm': 1, 'h': 2, 'b': 1, 'x': 1, 'i': 1, 'd': 1, 'y': 1, 'a': 1, 'v': 1, 'c': 1, 'j': 1, 'p': 1} 2
# 45 {'t': 3, 'x': 1} 3
# 46 {'f': 5, 'd': 1, 'o': 1, 'w': 1, 'e': 1, 'j': 1, 'z': 1, 'n': 1, 'a': 1, 's': 1} 5
# 48 {'l': 3, 'm': 3, 'z': 1} 3
# 57 {'z': 5, 's': 5, 'i': 5, 'd': 5, 'p': 5, 'e': 5, 'w': 5, 'b': 5, 'u': 5} 5
# 59 {'l': 1, 'p': 1, 's': 2, 'k': 2, 'r': 1, 'g': 1} 2
# ...
